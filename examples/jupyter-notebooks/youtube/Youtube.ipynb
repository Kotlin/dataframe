// %%
%useLatestDescriptors
%use dataframe
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@012be928db1deacaafbab5c94b96a297d8272f12/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
// }
// table.dataframe a {
//     cursor: pointer;
//     color: #296eaa;
//     text-decoration: none;
// }
// table.dataframe a:hover {
//     color: #1a466c;
//     text-decoration: underline;
// }
// table.dataframe tr:nth-child(odd) {
//     background: rgb(245, 245, 245);
// }
// table.dataframe tr:nth-child(even) {
//     background: #FFF
// }
// table.dataframe img {
//     max-width: fit-content;
// }
// table.dataframe tr:hover {
//     background: rgba(66, 165, 245, 0.2);
// }
// th.complex {
//     background-color: white;
//     border: 1px solid #ffffff;
// }
// table.dataframe th {
//     background-color: white;
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
//     vertical-align: top;
// }
// table.dataframe th.bottomBorder {
//     border-bottom-color: black;
// }
// table.dataframe {
//     border: none;
//     border-collapse: collapse;
// }
// table.dataframe .leftBorder {
//     border-left-color: #aaa;
// }
// table.dataframe .rightBorder {
//     border-right-color: #aaa;
// }
// table.dataframe .rightAlign {
//     text-align: right;
// }
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
//                 </style>
//                 <style>
//                 table.dataframe .null {
//     color: #b3b3cc;
// }
// table.dataframe .structural {
//     color: #737373;
//     font-weight: bold;
// }
// table.dataframe .numbers {
//     color: black;
// }
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
// table.dataframe td:hover > .formatted .structural {
//     color: black;
// }
// table.dataframe td:hover > .formatted .null {
//     color: black;
// }
//
//                 </style>

// %%
val apiKey = "YOUR API KEY"

// %%
fun load(path: String) = DataRow.read("https://www.googleapis.com/youtube/v3/$path&key=$apiKey")

// %%
fun load(path: String, maxPages: Int): AnyFrame {
    val rows = mutableListOf<AnyRow>()
    var pagePath = path
    do {
        val row = load(pagePath)
        rows.add(row)
        val next = row.getValueOrNull<String>("nextPageToken")
        pagePath = path + "&pageToken=" + next
    } while(next != null && rows.size < maxPages)
    return rows.concat()
}

// %%
val df = load("search?q=cute%20cats&maxResults=50&part=snippet", 5)
df
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1174405120"></table>
//
// <p>DataFrame: rowsCount = 5, columnsCount = 7</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"kind: String\">kind</span>", children: [], rightAlign: false, values: ["youtube#searchListResponse","youtube#searchListResponse","youtube#searchListResponse","youtube#searchListResponse","youtube#searchListResponse"] },
// { name: "<span title=\"etag: String\">etag</span>", children: [], rightAlign: false, values: ["t0xYnJRBpv0nfqH2a7IQAVVVs1A","ca9KZxruJK7H17GdWutwoduDmZo","4UZK1tVU7k9Ss4VIM3lLNaVN38E","LSbRI6bgdhCc9BAUpHw9edU-V4E","sFHLei6SGPtQDavXb4hb0Sm2iow"] },
// { name: "<span title=\"nextPageToken: String\">nextPageToken</span>", children: [], rightAlign: false, values: ["CDIQAA","CGQQAA","CJYBEAA","CMgBEAA","CPoBEAA"] },
// { name: "<span title=\"regionCode: String\">regionCode</span>", children: [], rightAlign: false, values: ["RU","RU","RU","RU","RU"] },
// { name: "<span title=\"totalResults: Int\">totalResults</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1000000</span></span>"] },
// { name: "<span title=\"resultsPerPage: Int\">resultsPerPage</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>"] },
// { name: "<span title=\"pageInfo: DataRow\">pageInfo</span>", children: [4, 5], rightAlign: false, values: ["<span class=\"formatted\" title=\"totalResults: 1000000\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">1000000</span><span class=\"structural\">, </span><span class=\"structural\">resultsPer...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"totalResults: 1000000\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">1000000</span><span class=\"structural\">, </span><span class=\"structural\">resultsPer...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"totalResults: 1000000\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">1000000</span><span class=\"structural\">, </span><span class=\"structural\">resultsPer...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"totalResults: 1000000\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">1000000</span><span class=\"structural\">, </span><span class=\"structural\">resultsPer...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"totalResults: 1000000\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">1000000</span><span class=\"structural\">, </span><span class=\"structural\">resultsPer...</span><span class=\"structural\"> }</span></span>"] },
// { name: "<span title=\"items: DataFrame\">items</span>", children: [], rightAlign: false, values: [{ frameId: 1174405121, value: "<b>DataFrame 50 x 4</b>" },{ frameId: 1174405122, value: "<b>DataFrame 50 x 4</b>" },{ frameId: 1174405123, value: "<b>DataFrame 50 x 4</b>" },{ frameId: 1174405124, value: "<b>DataFrame 50 x 4</b>" },{ frameId: 1174405125, value: "<b>DataFrame 50 x 4</b>" }] },
// { name: "<span title=\"prevPageToken: String?\">prevPageToken</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","CDIQAQ","CGQQAQ","CJYBEAE","CMgBEAE"] },
// ], id: 1174405120, rootId: 1174405120, totalRows: 5 } ) });
// /*-->*/
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"kind: String\">kind</span>", children: [], rightAlign: false, values: ["youtube#searchResult","youtube#searchResult","youtube#searchResult","youtube#searchResult","youtube#searchResult"] },
// { name: "<span title=\"etag: String\">etag</span>", children: [], rightAlign: false, values: ["b6kMsEg4PnSNJgLkIIZ-EHGkxbE","-yLoCcEP5TxEGwuDTLL52x7gKBg","jEdDDAXkwpJKTOPgAYFJaLA7hJM","pUBPtqwnECBBCkN24T5uUJgTimY","lSqpmrcGYfD-Refmvhx9PP8iyMc"] },
// { name: "<span title=\"kind: String\">kind</span>", children: [], rightAlign: false, values: ["youtube#video","youtube#video","youtube#video","youtube#video","youtube#video"] },
// { name: "<span title=\"videoId: String\">videoId</span>", children: [], rightAlign: false, values: ["uHKfrz65KSU","tpiyEe_CqB4","jHWKtQHXVJg","ufdw5Jc5ZHc","n3iNDf6cqzI"] },
// { name: "<span title=\"id: DataRow\">id</span>", children: [2, 3], rightAlign: false, values: ["<span class=\"formatted\" title=\"kind: youtube#video\nvideoId: uHKfrz65KSU\"><span class=\"structural\">{ </span><span class=\"structural\">kind: </span>youtube#video<span class=\"structural\">, </span><span class=\"structural\">videoId: </span>uHK<span class=\"structural\">...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"kind: youtube#video\nvideoId: tpiyEe_CqB4\"><span class=\"structural\">{ </span><span class=\"structural\">kind: </span>youtube#video<span class=\"structural\">, </span><span class=\"structural\">videoId: </span>tpi<span class=\"structural\">...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"kind: youtube#video\nvideoId: jHWKtQHXVJg\"><span class=\"structural\">{ </span><span class=\"structural\">kind: </span>youtube#video<span class=\"structural\">, </span><span class=\"structural\">videoId: </span>jHW<span class=\"structural\">...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"kind: youtube#video\nvideoId: ufdw5Jc5ZHc\"><span class=\"structural\">{ </span><span class=\"structural\">kind: </span>youtube#video<span class=\"structural\">, </span><span class=\"structural\">videoId: </span>ufd<span class=\"structural\">...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"kind: youtube#video\nvideoId: n3iNDf6cqzI\"><span class=\"structural\">{ </span><span class=\"structural\">kind: </span>youtube#video<span class=\"structural\">, </span><span class=\"structural\">videoId: </span>n3i<span class=\"structural\">...</span><span class=\"structural\"> }</span></span>"] },
// { name: "<span title=\"publishedAt: String\">publishedAt</span>", children: [], rightAlign: false, values: ["2019-12-11T19:43:05Z","2020-04-10T16:00:28Z","2019-11-01T01:35:36Z","2022-02-12T11:00:32Z","2022-01-17T18:41:31Z"] },
// { name: "<span title=\"channelId: String\">channelId</span>", children: [], rightAlign: false, values: ["UC8hC-augAnujJeprhjI0YkA","UCzn2gx8zzhF0A4Utk8TEDNQ","UC8hC-augAnujJeprhjI0YkA","UCZc2uoO8r22fuFhi-xNDE9A","UCYbggI6qVceWa1_1dfH0hMA"] },
// { name: "<span title=\"title: String\">title</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"Baby Cats - Cute and Funny Cat Videos Compilation #8 | Aww Animals\">Baby Cats - Cute and Fun

// %%
val items = df.items.concat()
items

// %%
val videos = items.dropNulls { id.videoId }
    .select { id.videoId named "id" and snippet }
    .distinct()
videos

// %%
val parsed = videos.parse()

// %%
val loaded = parsed.convert { dfsOf<URL>() }.with { IMG(it, maxHeight = 150) }
    .add("video") { IFRAME("http://www.youtube.com/embed/$id") }

// %%
val clean = loaded.move { snippet.channelId and snippet.channelTitle }.under("channel")
    .move { snippet.title and snippet.publishedAt }.toTop()
    .remove { snippet }
clean
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1174405126"></table>
//
// <p>... showing only top 20 of 241 rows</p><p>DataFrame: rowsCount = 241, columnsCount = 5</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"id: String\">id</span>", children: [], rightAlign: false, values: ["uHKfrz65KSU","tpiyEe_CqB4","jHWKtQHXVJg","ufdw5Jc5ZHc","n3iNDf6cqzI","eX2qFMC8cFo","ByH9LuSILxU","ZKBlMWI6nO4","QICzMzL7tIE","Qy6GLuWIX_c","Bat8Vd7WHeg","-8JQB_wXjmk","SB-qEYVdvXA","IJ5BnoakZrw","ZbfasEU8810","STdvxMRuEvY","zQIawgxoox4","MYmBYOIxe1c","KB-s_p4eIHE","cytJLvf-eVs"] },
// { name: "<span title=\"title: String\">title</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"Baby Cats - Cute and Funny Cat Videos Compilation #8 | Aww Animals\">Baby Cats - Cute and Funny Cat Videos<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Cute and Funny Cat Videos to Keep You Smiling! &#55357;&#56369;\">Cute and Funny Cat Videos to Keep You<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"
// { name: "<span title=\"channelId: String\">channelId</span>", children: [], rightAlign: false, values: ["UC8hC-augAnujJeprhjI0YkA","UCzn2gx8zzhF0A4Utk8TEDNQ","UC8hC-augAnujJeprhjI0YkA","UCZc2uoO8r22fuFhi-xNDE9A","UCYbggI6qVceWa1_1dfH0hMA","UCYPrd7A27nLhQONcCIfFTaA","UC8hC-augAnujJeprhjI0YkA","UCWoqASNf9byEBpuhsvPfz3w","UCyHKsRnmURYNnQJB34zzmkQ","UCZc2uoO8r22fuFhi-xNDE9A","UCyHKsRnmURYNnQJB34zzmkQ","UC8hC-augAnujJeprhjI0YkA","UCq5hgY37WAryZCwmehDyCaQ","UCYK1TyKyMxyDQU8c6zF8ltg","UCWoqASNf9byEBpuhsvPfz3w","UCeYBxAj3WJpu5Fot8XQbN1g","UC8hC-augAnujJeprhjI0YkA","UCWoqASNf9byEBpuhsvPfz3w","UCohSsWnJe18057ZcxBRW2yw","UC8hC-augAnujJeprhjI0YkA"] },
// { name: "<span title=\"channelTitle: String\">channelTitle</span>", children: [], rightAlign: false, values: ["Aww Animals","Rufus","Aww Animals","Funniest Cat Ever","Meowthemall","Funny Cats Life","Aww Animals","Cats Land","Funny Cats HD","Funniest Cat Ever","Funny Cats HD","Aww Animals","Funny Videos","Funny Pet Videos","Cats Land","Cutest Kittens City","Aww Animals","Cats Land","Funny Cats","Aww Animals"] },
// { name: "<span title=\"channel: DataRow\">channel</span>", children: [3, 4], rightAlign: false, values: ["<span class=\"formatted\" title=\"channelId: UC8hC-augAnujJeprhjI0YkA\nchannelTitle: Aww Animals\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UC8hC-augAnujJep<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UCzn2gx8zzhF0A4Utk8TEDNQ\nchannelTitle: Rufus\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UCzn2gx8zzhF0A4U<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UC8hC-augAnujJeprhjI0YkA\nchannelTitle: Aww Animals\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UC8hC-augAnujJep<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UCZc2uoO8r22fuFhi-xNDE9A\nchannelTitle: Funniest Cat Ever\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UCZc2uoO8r22fuFh<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UCYbggI6qVceWa1_1dfH0hMA\nchannelTitle: Meowthemall\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UCYbggI6qVceWa1_<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UCYPrd7A27nLhQONcCIfFTaA\nchannelTitle: Funny Cats Life\"><span class=\"structural\">{

// %%
val statPages = clean.id.chunked(50).map {
    val ids = it.joinToString("%2C")
    load("videos?part=statistics&id=$ids")
}
statPages
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1174405127"></table>
//
// <p>ColumnGroup: name = "id", rowsCount = 5, columnsCount = 4</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"kind: String\">kind</span>", children: [], rightAlign: false, values: ["youtube#videoListResponse","youtube#videoListResponse","youtube#videoListResponse","youtube#videoListResponse","youtube#videoListResponse"] },
// { name: "<span title=\"etag: String\">etag</span>", children: [], rightAlign: false, values: ["p7dDRmNlIDpognVkBG0fcGAMF6M","pfE3YXC2BWkPeAMxebhwqFqKcfQ","xTqxyybst7dYEQqJj_IuqJoMDG8","9Vdo5PfHmuHMzv8j7NEDZVXizJc","uzA3y9gLQggw5fq8rjqPDqlJ7jQ"] },
// { name: "<span title=\"items: DataFrame\">items</span>", children: [], rightAlign: false, values: [{ frameId: 1174405128, value: "<b>DataFrame 50 x 4</b>" },{ frameId: 1174405129, value: "<b>DataFrame 50 x 4</b>" },{ frameId: 1174405130, value: "<b>DataFrame 50 x 4</b>" },{ frameId: 1174405131, value: "<b>DataFrame 50 x 4</b>" },{ frameId: 1174405132, value: "<b>DataFrame 41 x 4</b>" }] },
// { name: "<span title=\"totalResults: Int\">totalResults</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">41</span></span>"] },
// { name: "<span title=\"resultsPerPage: Int\">resultsPerPage</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">41</span></span>"] },
// { name: "<span title=\"pageInfo: DataRow\">pageInfo</span>", children: [3, 4], rightAlign: false, values: ["<span class=\"formatted\" title=\"totalResults: 50\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">50</span><span class=\"structural\">, </span><span class=\"structural\">resultsPerPage: </span><span class=\"numbers\">50</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"totalResults: 50\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">50</span><span class=\"structural\">, </span><span class=\"structural\">resultsPerPage: </span><span class=\"numbers\">50</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"totalResults: 50\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">50</span><span class=\"structural\">, </span><span class=\"structural\">resultsPerPage: </span><span class=\"numbers\">50</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"totalResults: 50\nresultsPerPage: 50\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">50</span><span class=\"structural\">, </span><span class=\"structural\">resultsPerPage: </span><span class=\"numbers\">50</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"totalResults: 41\nresultsPerPage: 41\"><span class=\"structural\">{ </span><span class=\"structural\">totalResults: </span><span class=\"numbers\">41</span><span class=\"structural\">, </span><span class=\"structural\">resultsPerPage: </span><span class=\"numbers\">41</span><span class=\"structural\"> }</span></span>"] },
// ], id: 1174405127, rootId: 1174405127, totalRows: 5 } ) });
// /*-->*/
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"kind: String\">kind</span>", children: [], rightAlign: false, values: ["youtube#video","youtube#video","youtube#video","youtube#video","youtube#video"] },
// { name: "<span title=\"etag: String\">etag</span>", children: [], rightAlign: false, values: ["MR8KgHJnaMgpehbpU27NrWxK2Vw","LF6JVOuiW0DcK9q2SMB-gc4EmIk","myABpXY0sGYZnlcUU4QK5JrL1CI","fyx0n0WXLoxSItKp5Nb6NPk_iu8","ARm4OyQYcPgXezDuSsRdr4cGKJQ"] },
// { name: "<span title=\"id: String\">id</span>", children: [], rightAlign: false, values: ["uHKfrz65KSU","tpiyEe_CqB4","jHWKtQHXVJg","ufdw5Jc5ZHc","n3iNDf6cqzI"] },
// { name: "<span title=\"viewCount: String\">viewCount</span>", children: [], rightAlign: false, values: ["64591592","12221489","55132550","9372","112727"] },
// { name: "<span title=\"likeCount: String?\">likeCount</span>", children: [], rightAlign: false, values: ["614809","86878","389100","222","3262"] },
// { name: "<span title=\"favoriteCount: String\">favoriteCount</span>", children: [], rightAlign: false, values: ["0","0","0","0","0"] },
// { name: "<span title=\"commentCount: String?\">commentCount</span>", children: [], rightAlign: false, values: ["20921","4981","13424","35","112"] },
// { name: "<span title=\"statistics: DataRow\">statistics</span>", children: [3, 4, 5, 6], rightAlign: false, values: ["<span class=\"formatted\" title=\"viewCount: 64591592\nlikeCount: 614809\nfavoriteCount: 0\ncommentCount: 20921\"><span class=\"structural\">{ </span><span class=\"structural\">viewCount: </span>64591592<span class=\"structural\">, </span><span class=\"structural\">likeCou...</span><span class=\"structural\">, </span><span class=\"structural\">...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"viewCount: 12221489\nlikeCount: 86878\nfavoriteCount: 0\ncommentCount: 4981\"><span class=\"structural\">{ </span><span class=\"structural\">viewCount: </span>12221489<span class=\"structural\">, </span><span class=\"structural\">likeCou...</span><span class=\"structural\">, </span><span class=\"structural\">...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"viewCount: 55132550\nlikeCount: 389100\nfavoriteCount: 0\ncommentCount: 13424\"><span class=\"structural\">{ </span><span class=\"structural\">viewCount: </span>55132550<span class=\"structural\">, </span><span class=\"structural\">likeCou...</span><span class=\"structural\">, </span><span class=\"structural\">...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"viewCount: 9372\nlikeCount: 222\nfavoriteCount: 0\ncommentCount: 35\"><span class=\"structural\">{ </span><span class=\"structural\">viewCount: </span>9372<span class=\"structural\">, </span><span class=\"structural\">likeCount: </span>222<span class=\"structural\">, </span><span class=\"structural\">...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"viewCount: 112727\nlikeCount: 3262\nfavoriteCount: 0\ncommentCount: 112\"><span class=\"structural\">{ </span><span class=\"structural\">viewCount: </span>112727<span class=\"structural\">, </span><span class=\"structural\">likeCount...</span><span class=\"structural\">, </span><span class=\"structural\">...</span><span class=\"structural\"> }</span></span>"] },
// ], id: 1174405128, rootId: 1174405127, totalRows: 50 } ) });
// /*-->*/
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"kind: String\">kind</span>", children: [], rightAlign: false, values: ["youtube#video","youtube#video","youtube#video","youtube#video","youtube#video"] },
// { name: "<span title=\"etag: String\">etag</span>", children: [], rightAlign: f

// %%
val stats = statPages.items.concat().select { id and statistics.all() }.parse()
stats
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1174405133"></table>
//
// <p>... showing only top 20 of 241 rows</p><p>DataFrame: rowsCount = 241, columnsCount = 5</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"id: String\">id</span>", children: [], rightAlign: false, values: ["uHKfrz65KSU","tpiyEe_CqB4","jHWKtQHXVJg","ufdw5Jc5ZHc","n3iNDf6cqzI","eX2qFMC8cFo","ByH9LuSILxU","ZKBlMWI6nO4","QICzMzL7tIE","Qy6GLuWIX_c","Bat8Vd7WHeg","-8JQB_wXjmk","SB-qEYVdvXA","IJ5BnoakZrw","ZbfasEU8810","STdvxMRuEvY","zQIawgxoox4","MYmBYOIxe1c","KB-s_p4eIHE","cytJLvf-eVs"] },
// { name: "<span title=\"viewCount: Int\">viewCount</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">64591592</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12221489</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">55132550</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9372</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">112727</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">57927790</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">55719558</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">38676924</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">92985</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">133772</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150825</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">22017263</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">34886540</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6948503</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4397806</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">38474</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16626379</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">33819431</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">40689902</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">34017378</span></span>"] },
// { name: "<span title=\"likeCount: Int?\">likeCount</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">614809</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">86878</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">389100</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">222</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3262</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">871876</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">332059</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">380226</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">825</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1609</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1279</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">151959</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">229445</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">14969</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">21361</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">540</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">103753</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">223478</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">371347</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">237544</span></span>"] },
// { name: "<span title=\"favoriteCount: Int\">favoriteCount</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"commentCount: Int?\">commentCount</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">20921</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4981</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13424</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">35</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">112</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">24229</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12810</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10580</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">49</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">95</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">64</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5153</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18742</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">749</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">346</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">46</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3424</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5084</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11165</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4876</span></span>"] },
// ], id: 1174405133, rootId: 1174405133, totalRows: 241 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(1174405133) });
//
//
//         </script>
//         </html>

// %%
val joined = clean.join(stats)
joined
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1174405134"></table>
//
// <p>... showing only top 20 of 241 rows</p><p>DataFrame: rowsCount = 241, columnsCount = 9</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"id: String\">id</span>", children: [], rightAlign: false, values: ["uHKfrz65KSU","tpiyEe_CqB4","jHWKtQHXVJg","ufdw5Jc5ZHc","n3iNDf6cqzI","eX2qFMC8cFo","ByH9LuSILxU","ZKBlMWI6nO4","QICzMzL7tIE","Qy6GLuWIX_c","Bat8Vd7WHeg","-8JQB_wXjmk","SB-qEYVdvXA","IJ5BnoakZrw","ZbfasEU8810","STdvxMRuEvY","zQIawgxoox4","MYmBYOIxe1c","KB-s_p4eIHE","cytJLvf-eVs"] },
// { name: "<span title=\"title: String\">title</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"Baby Cats - Cute and Funny Cat Videos Compilation #8 | Aww Animals\">Baby Cats - Cute and Funny Cat Videos<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Cute and Funny Cat Videos to Keep You Smiling! &#55357;&#56369;\">Cute and Funny Cat Videos to Keep You<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Baby Cats - Cute and Funny Baby Cat Videos Compilation\">Baby Cats - Cute and Funny Baby Cat V<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Funny Cats &#55357;&#56889; - Don&#38;#39;t Try To Stop Laughing &#55358;&#56611; - Funniest Cats Ever\">Funny Cats &#55357;&#56889; - Don&#38;#39;t Try To Stop<span class=\"structural\">...</span></span>","Cute Cats for When You are Stressed","<span class=\"formatted\" title=\"Funniest Cats &#55357;&#56889; - Don&#38;#39;t try to hold back Laughter &#55357;&#56834; - Funny Cats Life\">Funniest Cats &#55357;&#56889; - Don&#38;#39;t try to h<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"
-augAnujJeprhjI0YkA","UCq5hgY37WAryZCwmehDyCaQ","UCYK1TyKyMxyDQU8c6zF8ltg","UCWoqASNf9byEBpuhsvPfz3w","UCeYBxAj3WJpu5Fot8XQbN1g","UC8hC-augAnujJeprhjI0YkA","UCWoqASNf9byEBpuhsvPfz3w","UCohSsWnJe18057ZcxBRW2yw","UC8hC-augAnujJeprhjI0YkA"] },
// { name: "<span title=\"channelTitle: String\">channelTitle</span>", children: [], rightAlign: false, values: ["Aww Animals","Rufus","Aww Animals","Funniest Cat Ever","Meowthemall","Funny Cats Life","Aww Animals","Cats Land","Funny Cats HD","Funniest Cat Ever","Funny Cats HD","Aww Animals","Funny Videos","Funny Pet Videos","Cats Land","Cutest Kittens City","Aww Animals","Cats Land","Funny Cats","Aww Animals"] },
// { name: "<span title=\"channel: DataRow\">channel</span>", children: [3, 4], rightAlign: false, values: ["<span class=\"formatted\" title=\"channelId: UC8hC-augAnujJeprhjI0YkA\nchannelTitle: Aww Animals\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UC8hC-augAnujJep<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UCzn2gx8zzhF0A4Utk8TEDNQ\nchannelTitle: Rufus\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UCzn2gx8zzhF0A4U<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UC8hC-augAnujJeprhjI0YkA\nchannelTitle: Aww Animals\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UC8hC-augAnujJep<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UCZc2uoO8r22fuFhi-xNDE9A\nchannelTitle: Funniest Cat Ever\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UCZc2uoO8r22fuFh<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UCYbggI6qVceWa1_1dfH0hMA\nchannelTitle: Meowthemall\"><span class=\"structural\">{ </span><span class=\"structural\">channelId: </span>UCYbggI6qVceWa1_<span class=\"structural\">...</span><span class=\"structural\">, </span><span class=\"structural\">c...</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"channelId: UCYPrd7A27nLhQONcCIfFTaA\nchannelTitle: Funny Cats Life\"><span class=\"structural\">{

// %%
val view by column<Int>()

val channels = joined.groupBy { channel }.sortByCount().aggregate {
    viewCount.sum() into view
    
    val last = maxBy { publishedAt }
    last.title into "last title"
    last.publishedAt into "time"
    last.viewCount into "viewCount"
}.sortByDesc(view).flatten()
channels
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1174405135"></table>
//
// <p>... showing only top 20 of 113 rows</p><p>DataFrame: rowsCount = 113, columnsCount = 6</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\
span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"funny cat videos | cute cat videos | cute animals | funny cats 804  #shorts\">funny cat videos | cute cat videos | <span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Too  Cute Cats and  Kittens videos Compilation\">Too  Cute Cats and  Kittens videos Co<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"So many cute kittens videos compilation 2018\">So many cute kittens videos compilati<span class=\"structural\">...</span></span>","Angry Cats &#55357;&#56894;","<span class=\"formatted\" title=\"Mother Cat And Kittens | Funny and Cute Cats Compilation #2 | CuteVN\">Mother Cat And Kittens | Funny and Cu<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Cat Reaction to Playing Balloon - Funny Cat Balloon Reaction Compilation 2019\">Cat Reaction to Playing Balloon - Fun<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Epic Funny Cats / Cute Cats Compilation  -  60 minutes!! [HD][HQ]\">Epic Funny Cats / Cute Cats Compilati<span class=\"structural\">...</span></span>"] },
// { name: "<span title=\"time: kotlinx.datetime.Instant\">time</span>", children: [], rightAlign: false, values: ["2014-08-05T18:56:38Z","2021-11-15T11:41:38Z","2020-08-11T11:32:45Z","2017-11-18T21:00:00Z","2018-09-27T08:08:38Z","2017-05-31T09:30:02Z","2014-08-29T15:55:06Z","2022-01-30T06:00:01Z","2018-04-24T21:00:04Z","2022-02-04T15:00:11Z","2020-06-15T11:19:45Z","2021-01-02T23:45:00Z","2015-09-05T06:00:17Z","2021-08-05T13:42:37Z","2016-07-26T12:42:10Z","2018-03-19T02:00:25Z","2021-11-21T09:18:33Z","2020-05-09T10:00:28Z","2019-11-26T19:10:13Z","2012-10-17T21:09:11Z"] },
// { name: "<span title=\"viewCount: Int\">viewCount</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">43108529</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4901678</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15740783</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">287269391</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">214355957</span></span>","<span class=\"

// %%
%use lets-plot
// Out:
//    <div id="QHKbSM"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.2.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("QHKbSM").appendChild(div);
//            };
//            var e = document.getElementById("QHKbSM");
//            e.appendChild(script);
//        })();
//    </script>

// %%
letsPlot(channels.sortBy { viewCount.desc() }.toMap()) +
    geomBar(stat = Stat.identity) {
        x = "channelTitle"
        y = "viewCount"
    }
// Out:
//    <div id="Ckf5Gj"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"channelTitle",
// "y":"viewCount"
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// "viewCount":[2.87269391E8,2.14355957E8,1.15539241E8,1.03211501E8,8.5376951E7,5.0001446E7,4.3108529E7,4.0081068E7,3.954888E7,3.488654E7,3.3952774E7,3.0013145E7,2.8072588E7,2.4699439E7,2.1593077E7,1.8460016E7,1.7928927E7,1.7513384E7,1.604393E7,1.5740783E7,1.4644095E7,1.3582311E7,1.2221489E7,1.1508146E7,8681255.0,8248711.0,6948503.0,6585043.0,5967258.0,5667980.0,4901678.0,4751726.0,3935736.0,2696055.0,2661254.0,2289634.0,2250012.0,1885278.0,1687615.0,1546096.0,1397069.0,1269943.0,981462.0,922904.0,834029.0,825552.0,783985.0,440357.0,397186.0,358327.0,331915.0,26097.0,2346.0],
